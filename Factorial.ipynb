# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishk25bcon2604/python-25bcon2604/blob/main/Factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 5
fact = 1

for i in range(1, n + 1):
    fact = fact * i

print("Factorial of", n, "=", fact)
# Out:
# Factorial of 5 = 120
